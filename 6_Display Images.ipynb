# %%
from IPython import display

# %%
display.Image("Image/Image3.png")

# %%
display.Image("Image/train.drawio.png")

# %%
display.Image("Image/rest-api.drawio.png")

# %%
display.Image("Image/monitoring.drawio.png")

# %%
display.Image("Image/ks-test.drawio.png")

# %%
display.Image("Image/paired-t.drawio.png")

# %%
display.Image("Image/psi-test.drawio.png")

# %%
display.Image("Image/shap.drawio.png")

# %%
display.Image("Image/drift.drawio.png")

# %%
display.Image("Image/aws-processing-job.drawio.png")

# %%
display.Image("Image/aws-processing-map.drawio.png")

# %%
display.Image("Image/aws-training-data-map.drawio.png")

# %%
display.Image("Image/aws-training-job.drawio.png")

# %%
display.Image("Image/azure-processing-map.drawio.png")

# %%
display.Image("Image/azure-training-map.drawio.png")

# %%
display.Image("Image/devops-cycle.png")

# %%
display.Image("Image/git-branch.drawio.png")

# %%
display.Image("Image/git-workflow.drawio.png")

# %%
display.Image("Image/pipeline.drawio.png")
